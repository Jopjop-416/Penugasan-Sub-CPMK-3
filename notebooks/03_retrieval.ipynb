# %% [markdown]
# # Stage 3 - Case Retrieval
#
# This notebook documents TF-IDF vectorization, retrieval, and query generation for evaluation.

# %% [markdown]
# ## Run
#
# ```bash
# python 03_retrieval.py
# ```
#
# Optional interactive demo:
#
# ```bash
# python 03_retrieval.py --interactive
# ```

# %% [markdown]
# ## Output
#
# - `models/tfidf_vectorizer.pkl`
# - `models/tfidf_matrix.pkl`
# - `models/case_ids.pkl`
# - `data/eval/queries.json`
# - `data/eval/retrieval_initial.json`
# - `logs/retrieval.log`
