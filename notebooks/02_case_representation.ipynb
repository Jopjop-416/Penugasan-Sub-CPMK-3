# %% [markdown]
# # Stage 2 - Case Representation
#
# This notebook documents the extraction of case metadata and key textual features into `cases.csv` and `cases.json`.

# %% [markdown]
# ## Run
#
# ```bash
# python 02_case_representation.py
# ```

# %% [markdown]
# ## Output
#
# - `data/processed/cases.csv`
# - `data/processed/cases.json`
# - `logs/representation.log`
