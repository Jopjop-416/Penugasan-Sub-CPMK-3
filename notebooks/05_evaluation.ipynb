# %% [markdown]
# # Stage 5 - Model Evaluation
#
# This notebook documents the evaluation metrics and error analysis for retrieval and solution reuse.

# %% [markdown]
# ## Run
#
# ```bash
# python 05_evaluation.py
# ```

# %% [markdown]
# ## Output
#
# - `data/eval/retrieval_metrics.csv`
# - `data/eval/prediction_metrics.csv`
# - `logs/evaluation.log`
