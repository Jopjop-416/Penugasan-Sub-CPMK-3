# %% [markdown]
# # Stage 4 - Case Solution Reuse
#
# This notebook documents how retrieved cases are reused to predict the solution for new queries.

# %% [markdown]
# ## Run
#
# ```bash
# python 04_predict.py
# ```

# %% [markdown]
# ## Output
#
# - `data/results/predictions.csv`
# - `logs/predict.log`
