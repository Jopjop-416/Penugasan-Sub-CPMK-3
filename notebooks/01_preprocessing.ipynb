# %% [markdown]
# # Stage 1 - Preprocessing
#
# This notebook documents how the raw PDF judgments are cleaned and converted into text files under `data/raw/`.

# %% [markdown]
# ## Run
#
# ```bash
# python 01_preprocessing.py
# ```

# %% [markdown]
# ## Output
#
# - `data/raw/case_*.txt`
# - `logs/cleaning.log`
